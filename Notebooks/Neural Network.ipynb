# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import matthews_corrcoef
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
import scipy.stats as stats
from tensorflow import keras
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
#Functions

def evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    errors = abs(predictions - y_test)
    mape = 100 * np.mean(errors / y_test)
    accuracy = 100 - mape
    roc = roc_auc_score(y_test, predictions)
    print('Model Performance')
    print('Average Error: {:0.4f} degrees'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%'.format(accuracy))
    print(f'AUC = {roc}')
    return accuracy

# %%
features = pd.read_csv('../Data/training_set_features.csv')
labels = pd.read_csv('../Data/training_set_labels.csv')

df = pd.merge(features, labels, on='respondent_id', how='inner')

# %%
df['sex'] = df['sex'].map({
    'Female': 0,
    'Male': 1
})

df['marital_status'] = df['marital_status'].map({
    'Not Married': 0,
    'Married': 1
})

df['rent_or_own'] = df['rent_or_own'].map({
    'Rent': 0,
    'Own': 1
})
    
h1n1_num_cols = [
    'opinion_h1n1_sick_from_vacc',
    'h1n1_concern',
    'h1n1_knowledge',
    'opinion_seas_vacc_effective',
    'opinion_h1n1_vacc_effective',
    'opinion_seas_risk',
    'opinion_h1n1_risk',
    'child_under_6_months',
    'marital_status',
    'rent_or_own',
    'behavioral_touch_face',
    'behavioral_face_mask',
    'chronic_med_condition',
    'behavioral_wash_hands',
    'doctor_recc_seasonal',
    'doctor_recc_h1n1'
]

h1n1_cat_cols = [
    'age_group',
    'hhs_geo_region',
    'income_poverty'
]

seas_num_cols = [
    'behavioral_wash_hands',
    'opinion_h1n1_vacc_effective',
    'opinion_h1n1_risk',
    'opinion_seas_vacc_effective',
    'opinion_seas_risk',
    'marital_status',
    'chronic_med_condition',
    'rent_or_own',
    'doctor_recc_h1n1',
    'doctor_recc_seasonal'
]

seas_cat_cols = [
    'age_group',
    'income_poverty'
]

h1n1_cols = h1n1_num_cols + h1n1_cat_cols
seas_cols = seas_num_cols + seas_cat_cols

num_cols = list(set(h1n1_num_cols + seas_num_cols))
cat_cols = list(set(h1n1_cat_cols + seas_cat_cols))

all_cols = list(set(num_cols + cat_cols))

# %%
opinion_h1n1_sick_from_vacc_mean = df['opinion_h1n1_sick_from_vacc'].mean()
h1n1_concern_mean = df['h1n1_concern'].mean()
h1n1_knowledge_mean = df['h1n1_knowledge'].mean()
opinion_seas_vacc_effective_mean = df['opinion_seas_vacc_effective'].mean()
opinion_h1n1_vacc_effective_mean = df['opinion_h1n1_vacc_effective'].mean()
opinion_seas_risk_mean = df['opinion_seas_risk'].mean()
opinion_h1n1_risk_mean = df['opinion_h1n1_risk'].mean()
behavioral_wash_hands_mean = df['behavioral_wash_hands'].mean()
sex_mean = df['sex'].mean()
child_under_6_months_mean = df['child_under_6_months'].mean()
marital_status_mean = df['marital_status'].mean()
rent_or_own_mean = df['rent_or_own'].mean()
behavioral_touch_face_mean = df['behavioral_touch_face'].mean()
behavioral_face_mask_mean = df['behavioral_face_mask'].mean()
chronic_med_condition_mean = df['chronic_med_condition'].mean()
doctor_recc_seasonal_mean = df['doctor_recc_seasonal'].mean()
doctor_recc_h1n1_mean = df['doctor_recc_h1n1'].mean()

df['opinion_h1n1_sick_from_vacc'] = df['opinion_h1n1_sick_from_vacc'].fillna(opinion_h1n1_sick_from_vacc_mean)
df['h1n1_concern'] = df['h1n1_concern'].fillna(h1n1_concern_mean)
df['h1n1_knowledge'] = df['h1n1_knowledge'].fillna(h1n1_knowledge_mean)
df['opinion_seas_vacc_effective'] = df['opinion_seas_vacc_effective'].fillna(opinion_seas_vacc_effective_mean)
df['opinion_h1n1_vacc_effective'] = df['opinion_h1n1_vacc_effective'].fillna(opinion_h1n1_vacc_effective_mean)
df['opinion_seas_risk'] = df['opinion_seas_risk'].fillna(opinion_seas_risk_mean)
df['opinion_h1n1_risk'] = df['opinion_h1n1_risk'].fillna(opinion_h1n1_risk_mean)
df['behavioral_wash_hands'] = df['behavioral_wash_hands'].fillna(behavioral_wash_hands_mean)
df['sex'] = df['sex'].fillna(sex_mean)
df['child_under_6_months'] = df['child_under_6_months'].fillna(child_under_6_months_mean)
df['marital_status'] = df['marital_status'].fillna(marital_status_mean)
df['rent_or_own'] = df['rent_or_own'].fillna(rent_or_own_mean)
df['behavioral_touch_face'] = df['behavioral_touch_face'].fillna(behavioral_touch_face_mean)
df['behavioral_face_mask'] = df['behavioral_face_mask'].fillna(behavioral_face_mask_mean)
df['chronic_med_condition'] = df['chronic_med_condition'].fillna(chronic_med_condition_mean)
df['doctor_recc_seasonal'] = df['doctor_recc_seasonal'].fillna(doctor_recc_seasonal_mean)
df['doctor_recc_h1n1'] = df['doctor_recc_h1n1'].fillna(doctor_recc_h1n1_mean)

df['age_group'] = df['age_group'].fillna('None')
df['income_poverty'] = df['income_poverty'].fillna('None')
df['hhs_geo_region'] = df['hhs_geo_region'].fillna('None')

# %%
all_cols
# Out:
# ['marital_status',
#  'age_group',
#  'h1n1_concern',
#  'h1n1_knowledge',
#  'behavioral_wash_hands',
#  'income_poverty',
#  'opinion_seas_vacc_effective',
#  'child_under_6_months',
#  'chronic_med_condition',
#  'doctor_recc_h1n1',
#  'opinion_h1n1_vacc_effective',
#  'opinion_seas_risk',
#  'behavioral_face_mask',
#  'doctor_recc_seasonal',
#  'opinion_h1n1_sick_from_vacc',
#  'behavioral_touch_face',
#  'opinion_h1n1_risk',
#  'hhs_geo_region',
#  'rent_or_own']

# %% [markdown]
# # Preprocessing

# %%
X = df[all_cols]
y_h1n1 = df[['h1n1_vaccine']]
y_seas = df[['seasonal_vaccine']]
y = df[['h1n1_vaccine', 'seasonal_vaccine']]

# %%
#Categorical
cat_df = X[cat_cols]
recat_df = pd.get_dummies(data=cat_df, drop_first=True)

#Numerical
num_df = X[num_cols]

scaler = StandardScaler()
scaled_num = scaler.fit_transform(num_df)
scaled_num_df = pd.DataFrame(scaled_num, index=num_df.index, columns=num_df.columns)

encoded_df = pd.concat([recat_df, scaled_num_df], axis=1)

encoded_df['opinion_seas_risk'] = encoded_df['opinion_seas_risk'] * 1
encoded_df['opinion_h1n1_risk'] = encoded_df['opinion_h1n1_risk'] * 1

# %% [markdown]
# ### Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(encoded_df, y, test_size=0.3, random_state=42)

y_train_h1n1 = y_train['h1n1_vaccine']
y_train_seas = y_train['seasonal_vaccine']

y_test_h1n1 = y_test['h1n1_vaccine']
y_test_seas = y_test['seasonal_vaccine']

# %%
X_train = np.asarray(X_train)
X_test = np.asarray(X_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

y_train_h1n1 = np.asarray(y_train_h1n1)
y_test_h1n1 = np.asarray(y_test_h1n1)

y_train_seas = np.asarray(y_train_seas)
y_test_seas = np.asarray(y_test_seas)

# %% [markdown]
# # Random Forest

# %% [markdown]
# ### H1N1 Model

# %%
#H1N1 Model
model_h1n1 = RandomForestRegressor(n_estimators=800,
                              min_samples_split=2,
                              min_samples_leaf=4,
                              max_features='sqrt',
                              max_depth=20,
                              bootstrap=False)
model_h1n1.fit(X_train, y_train_h1n1)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=20, max_features='sqrt',
#                       min_samples_leaf=4, n_estimators=800)

# %%
#Base Model
base_model = RandomForestRegressor(n_estimators=10, random_state=42)
base_model.fit(X_train, y_train_h1n1)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
evaluate(base_model, X_test, y_test_h1n1)
# Out:
# Model Performance
# Average Error: 0.2510 degrees
# Accuracy = nan%
# AUC = 0.7644042825062549
# nan

# %%
evaluate(model_h1n1, X_test, y_test_h1n1)
# Out:
# Model Performance
# Average Error: 0.2464 degrees
# Accuracy = -inf%
# AUC = 0.8231329195341048
# -inf

# %%
y_predicted_h1n1 = model_h1n1.predict(X_test)

# %% [markdown]
# ### Seasonal Model

# %%
#Seasonal Model
model_seas = RandomForestRegressor(n_estimators=800,
                              min_samples_split=2,
                              min_samples_leaf=4,
                              max_features='sqrt',
                              max_depth=20,
                              bootstrap=False)

model_seas.fit(X_train, y_train_seas)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=20, max_features='sqrt',
#                       min_samples_leaf=4, n_estimators=800)

# %%
#Base Model
base_model = RandomForestRegressor(n_estimators=10, random_state=42)
base_model.fit(X_train, y_train_seas)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
evaluate(base_model, X_test, y_test_seas)
# Out:
# Model Performance
# Average Error: 0.3313 degrees
# Accuracy = nan%
# AUC = 0.7933126371358868
# nan

# %%
evaluate(model_seas, X_test, y_test_seas)
# Out:
# Model Performance
# Average Error: 0.3294 degrees
# Accuracy = -inf%
# AUC = 0.8466392132441946
# -inf

# %%
y_predicted_seas = model_seas.predict(X_test)

# %%
y_predicted = np.vstack((y_predicted_h1n1, y_predicted_seas)).T

# %%
roc_auc_score(y_test, y_predicted)
# Out:
# 0.8348860663891498

# %% [markdown]
# # Neural Network

# %% [markdown]
# ### H1N1

# %%
h1n1_mc = ModelCheckpoint('..Models/h1n1_best_model.h5', monitor='val_auc', mode='max', verbose=1, save_best_only=True)

model_h1n1 = keras.Sequential([
    keras.layers.Dense(100, activation='hard_sigmoid', input_dim=32),
    keras.layers.LeakyReLU(500),
    keras.layers.LeakyReLU(800),
    keras.layers.LeakyReLU(200),
    keras.layers.Dense(200, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_h1n1.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=[tf.keras.metrics.AUC(from_logits=True)])

# %%
history = model_h1n1.fit(
    X_train,
    y_train_h1n1,
    batch_size=200,
    epochs=150,
    validation_data=(X_test, y_test_h1n1),
    callbacks=[h1n1_mc]
)
# Out:
# Epoch 1/150
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4531 - auc: 0.7393 - val_loss: 0.4084 - val_auc: 0.7995
#
# Epoch 00001: val_auc improved from -inf to 0.79946, saving model to ..Models\h1n1_best_model.h5
# Epoch 2/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3994 - auc: 0.8144 - val_loss: 0.3984 - val_auc: 0.8118
#
# Epoch 00002: val_auc improved from 0.79946 to 0.81182, saving model to ..Models\h1n1_best_model.h5
# Epoch 3/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3933 - auc: 0.8221 - val_loss: 0.3961 - val_auc: 0.8148
#
# Epoch 00003: val_auc improved from 0.81182 to 0.81478, saving model to ..Models\h1n1_best_model.h5
# Epoch 4/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3928 - auc: 0.8219 - val_loss: 0.3973 - val_auc: 0.8148
#
# Epoch 00004: val_auc improved from 0.81478 to 0.81482, saving model to ..Models\h1n1_best_model.h5
# Epoch 5/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3921 - auc: 0.8231 - val_loss: 0.3946 - val_auc: 0.8173
#
# Epoch 00005: val_auc improved from 0.81482 to 0.81730, saving model to ..Models\h1n1_best_model.h5
# Epoch 6/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3924 - auc: 0.8230 - val_loss: 0.3995 - val_auc: 0.8175
#
# Epoch 00006: val_auc improved from 0.81730 to 0.81753, saving model to ..Models\h1n1_best_model.h5
# Epoch 7/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3917 - auc: 0.8231 - val_loss: 0.3939 - val_auc: 0.8182
#
# Epoch 00007: val_auc improved from 0.81753 to 0.81816, saving model to ..Models\h1n1_best_model.h5
# Epoch 8/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3909 - auc: 0.8245 - val_loss: 0.3929 - val_auc: 0.8193
#
# Epoch 00008: val_auc improved from 0.81816 to 0.81931, saving model to ..Models\h1n1_best_model.h5
# Epoch 9/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3898 - auc: 0.8255 - val_loss: 0.3959 - val_auc: 0.8190
#
# Epoch 00009: val_auc did not improve from 0.81931
# Epoch 10/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3901 - auc: 0.8257 - val_loss: 0.3935 - val_auc: 0.8204
#
# Epoch 00010: val_auc improved from 0.81931 to 0.82037, saving model to ..Models\h1n1_best_model.h5
# Epoch 11/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3891 - auc: 0.8268 - val_loss: 0.3944 - val_auc: 0.8205
#
# Epoch 00011: val_auc improved from 0.82037 to 0.82052, saving model to ..Models\h1n1_best_model.h5
# Epoch 12/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3881 - auc: 0.8275 - val_loss: 0.3914 - val_auc: 0.8208
#
# Epoch 00012: val_auc improved from 0.82052 to 0.82085, saving model to ..Models\h1n1_best_model.h5
# Epoch 13/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3886 - auc: 0.8273 - val_loss: 0.3952 - val_auc: 0.8202
#
# Epoch 00013: val_auc did not improve from 0.82085
# Epoch 14/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3888 - auc: 0.8264 - val_loss: 0.3916 - val_auc: 0.8217
#
# Epoch 00014: val_auc improved from 0.82085 to 0.82173, saving model to ..Models\h1n1_best_model.h5
# Epoch 15/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3880 - auc: 0.8275 - val_loss: 0.3917 - val_auc: 0.8207
#
# Epoch 00015: val_auc did not improve from 0.82173
# Epoch 16/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3886 - auc: 0.8270 - val_loss: 0.3942 - val_auc: 0.8219
#
# Epoch 00016: val_auc improved from 0.82173 to 0.82187, saving model to ..Models\h1n1_best_model.h5
# Epoch 17/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3882 - auc: 0.8275 - val_loss: 0.3896 - val_auc: 0.8225
#
# Epoch 00017: val_auc improved from 0.82187 to 0.82246, saving model to ..Models\h1n1_best_model.h5
# Epoch 18/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3869 - auc: 0.8287 - val_loss: 0.3904 - val_auc: 0.8219
#
# Epoch 00018: val_auc did not improve from 0.82246
# Epoch 19/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3871 - auc: 0.8282 - val_loss: 0.3925 - val_auc: 0.8217
#
# Epoch 00019: val_auc did not improve from 0.82246
# Epoch 20/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3845 - auc: 0.8313 - val_loss: 0.3907 - val_auc: 0.8208
#
# Epoch 00020: val_auc did not improve from 0.82246
# Epoch 21/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3849 - auc: 0.8299 - val_loss: 0.3950 - val_auc: 0.8222
#
# Epoch 00021: val_auc did not improve from 0.82246
# Epoch 22/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3844 - auc: 0.8317 - val_loss: 0.3892 - val_auc: 0.8235
#
# Epoch 00022: val_auc improved from 0.82246 to 0.82355, saving model to ..Models\h1n1_best_model.h5
# Epoch 23/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3837 - auc: 0.8319 - val_loss: 0.3898 - val_auc: 0.8221
#
# Epoch 00023: val_auc did not improve from 0.82355
# Epoch 24/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3828 - auc: 0.8324 - val_loss: 0.3931 - val_auc: 0.8236
#
# Epoch 00024: val_auc improved from 0.82355 to 0.82361, saving model to ..Models\h1n1_best_model.h5
# Epoch 25/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3844 - auc: 0.8312 - val_loss: 0.3905 - val_auc: 0.8227
#
# Epoch 00025: val_auc did not improve from 0.82361
# Epoch 26/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3824 - auc: 0.8331 - val_loss: 0.3886 - val_auc: 0.8232
#
# Epoch 00026: val_auc did not improve from 0.82361
# Epoch 27/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3833 - auc: 0.8328 - val_loss: 0.3892 - val_auc: 0.8243
#
# Epoch 00027: val_auc improved from 0.82361 to 0.82427, saving model to ..Models\h1n1_best_model.h5
# Epoch 28/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3818 - auc: 0.8331 - val_loss: 0.3894 - val_auc: 0.8234
#
# Epoch 00028: val_auc did not improve from 0.82427
# Epoch 29/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3831 - auc: 0.8324 - val_loss: 0.3884 - val_auc: 0.8235
#
# Epoch 00029: val_auc did not improve from 0.82427
# Epoch 30/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3816 - auc: 0.8336 - val_loss: 0.3883 - val_auc: 0.8243
#
# Epoch 00030: val_auc did not improve from 0.82427
# Epoch 31/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3829 - auc: 0.8331 - val_loss: 0.3897 - val_auc: 0.8229
#
# Epoch 00031: val_auc did not improve from 0.82427
# Epoch 32/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3815 - auc: 0.8339 - val_loss: 0.3908 - val_auc: 0.8229
#
# Epoch 00032: val_auc did not improve from 0.82427
# Epoch 33/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3813 - auc: 0.8340 - val_loss: 0.3890 - val_auc: 0.8232
#
# Epoch 00033: val_auc did not improve from 0.82427
# Epoch 34/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3814 - auc: 0.8336 - val_loss: 0.3896 - val_auc: 0.8232
#
# Epoch 00034: val_auc did not improve from 0.82427
# Epoch 35/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3798 - auc: 0.8354 - val_loss: 0.3903 - val_auc: 0.8244
#
# Epoch 00035: val_auc improved from 0.82427 to 0.82440, saving model to ..Models\h1n1_best_model.h5
# Epoch 36/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3801 - auc: 0.8350 - val_loss: 0.3922 - val_auc: 0.8222
#
# Epoch 00036: val_auc did not improve from 0.82440
# Epoch 37/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3813 - auc: 0.8340 - val_loss: 0.3893 - val_auc: 0.8237
#
# Epoch 00037: val_auc did not improve from 0.82440
# Epoch 38/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3798 - auc: 0.8351 - val_loss: 0.3889 - val_auc: 0.8230
#
# Epoch 00038: val_auc did not improve from 0.82440
# Epoch 39/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3800 - auc: 0.8358 - val_loss: 0.3908 - val_auc: 0.8221
#
# Epoch 00039: val_auc did not improve from 0.82440
# Epoch 40/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3790 - auc: 0.8364 - val_loss: 0.3895 - val_auc: 0.8237
#
# Epoch 00040: val_auc did not improve from 0.82440
# Epoch 41/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3802 - auc: 0.8350 - val_loss: 0.3897 - val_auc: 0.8239
#
# Epoch 00041: val_auc did not improve from 0.82440
# Epoch 42/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3792 - auc: 0.8365 - val_loss: 0.3895 - val_auc: 0.8240
#
# Epoch 00042: val_auc did not improve from 0.82440
# Epoch 43/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3791 - auc: 0.8361 - val_loss: 0.3897 - val_auc: 0.8230
#
# Epoch 00043: val_auc did not improve from 0.82440
# Epoch 44/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3792 - auc: 0.8357 - val_loss: 0.3927 - val_auc: 0.8229
#
# Epoch 00044: val_auc did not improve from 0.82440
# Epoch 45/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3785 - auc: 0.8367 - val_loss: 0.3905 - val_auc: 0.8241
#
# Epoch 00045: val_auc did not improve from 0.82440
# Epoch 46/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3785 - auc: 0.8363 - val_loss: 0.3905 - val_auc: 0.8233
#
# Epoch 00046: val_auc did not improve from 0.82440
# Epoch 47/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3781 - auc: 0.8368 - val_loss: 0.3921 - val_auc: 0.8229
#
# Epoch 00047: val_auc did not improve from 0.82440
# Epoch 48/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3777 - auc: 0.8376 - val_loss: 0.3900 - val_auc: 0.8225
#
# Epoch 00048: val_auc did not improve from 0.82440
# Epoch 49/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3782 - auc: 0.8370 - val_loss: 0.3887 - val_auc: 0.8239
#
# Epoch 00049: val_auc did not improve from 0.82440
# Epoch 50/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3778 - auc: 0.8373 - val_loss: 0.3902 - val_auc: 0.8242
#
# Epoch 00050: val_auc did not improve from 0.82440
# Epoch 51/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3772 - auc: 0.8378 - val_loss: 0.3887 - val_auc: 0.8233
#
# Epoch 00051: val_auc did not improve from 0.82440
# Epoch 52/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3769 - auc: 0.8384 - val_loss: 0.3884 - val_auc: 0.8247
#
# Epoch 00052: val_auc improved from 0.82440 to 0.82472, saving model to ..Models\h1n1_best_model.h5
# Epoch 53/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3766 - auc: 0.8385 - val_loss: 0.3896 - val_auc: 0.8232
#
# Epoch 00053: val_auc did not improve from 0.82472
# Epoch 54/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3765 - auc: 0.8392 - val_loss: 0.3891 - val_auc: 0.8235
#
# Epoch 00054: val_auc did not improve from 0.82472
# Epoch 55/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3762 - auc: 0.8391 - val_loss: 0.3888 - val_auc: 0.8240
#
# Epoch 00055: val_auc did not improve from 0.82472
# Epoch 56/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3759 - auc: 0.8391 - val_loss: 0.3903 - val_auc: 0.8236
#
# Epoch 00056: val_auc did not improve from 0.82472
# Epoch 57/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3756 - auc: 0.8399 - val_loss: 0.3882 - val_auc: 0.8239
#
# Epoch 00057: val_auc did not improve from 0.82472
# Epoch 58/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3761 - auc: 0.8395 - val_loss: 0.3885 - val_auc: 0.8237
#
# Epoch 00058: val_auc did not improve from 0.82472
# Epoch 59/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3748 - auc: 0.8402 - val_loss: 0.3902 - val_auc: 0.8241
#
# Epoch 00059: val_auc did not improve from 0.82472
# Epoch 60/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3753 - auc: 0.8395 - val_loss: 0.3899 - val_auc: 0.8244
#
# Epoch 00060: val_auc did not improve from 0.82472
# Epoch 61/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3761 - auc: 0.8388 - val_loss: 0.3900 - val_auc: 0.8232
#
# Epoch 00061: val_auc did not improve from 0.82472
# Epoch 62/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3744 - auc: 0.8410 - val_loss: 0.3893 - val_auc: 0.8232
#
# Epoch 00062: val_auc did not improve from 0.82472
# Epoch 63/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3757 - auc: 0.8392 - val_loss: 0.3890 - val_auc: 0.8242
#
# Epoch 00063: val_auc did not improve from 0.82472
# Epoch 64/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3735 - auc: 0.8416 - val_loss: 0.3886 - val_auc: 0.8246
#
# Epoch 00064: val_auc did not improve from 0.82472
# Epoch 65/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3737 - auc: 0.8416 - val_loss: 0.3884 - val_auc: 0.8253
#
# Epoch 00065: val_auc improved from 0.82472 to 0.82535, saving model to ..Models\h1n1_best_model.h5
# Epoch 66/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3747 - auc: 0.8394 - val_loss: 0.3896 - val_auc: 0.8236
#
# Epoch 00066: val_auc did not improve from 0.82535
# Epoch 67/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3736 - auc: 0.8416 - val_loss: 0.3889 - val_auc: 0.8235
#
# Epoch 00067: val_auc did not improve from 0.82535
# Epoch 68/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3730 - auc: 0.8426 - val_loss: 0.3898 - val_auc: 0.8246
#
# Epoch 00068: val_auc did not improve from 0.82535
# Epoch 69/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3722 - auc: 0.8427 - val_loss: 0.3886 - val_auc: 0.8242
#
# Epoch 00069: val_auc did not improve from 0.82535
# Epoch 70/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3719 - auc: 0.8432 - val_loss: 0.3899 - val_auc: 0.8234
#
# Epoch 00070: val_auc did not improve from 0.82535
# Epoch 71/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3722 - auc: 0.8432 - val_loss: 0.3900 - val_auc: 0.8229
#
# Epoch 00071: val_auc did not improve from 0.82535
# Epoch 72/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3723 - auc: 0.8422 - val_loss: 0.3897 - val_auc: 0.8229
#
# Epoch 00072: val_auc did not improve from 0.82535
# Epoch 73/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3714 - auc: 0.8432 - val_loss: 0.3943 - val_auc: 0.8243
#
# Epoch 00073: val_auc did not improve from 0.82535
# Epoch 74/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3715 - auc: 0.8436 - val_loss: 0.3907 - val_auc: 0.8222
#
# Epoch 00074: val_auc did not improve from 0.82535
# Epoch 75/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3710 - auc: 0.8439 - val_loss: 0.3895 - val_auc: 0.8228
#
# Epoch 00075: val_auc did not improve from 0.82535
# Epoch 76/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3709 - auc: 0.8443 - val_loss: 0.3882 - val_auc: 0.8245
#
# Epoch 00076: val_auc did not improve from 0.82535
# Epoch 77/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3706 - auc: 0.8444 - val_loss: 0.3897 - val_auc: 0.8234
#
# Epoch 00077: val_auc did not improve from 0.82535
# Epoch 78/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3705 - auc: 0.8441 - val_loss: 0.3916 - val_auc: 0.8220
#
# Epoch 00078: val_auc did not improve from 0.82535
# Epoch 79/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3704 - auc: 0.8447 - val_loss: 0.3893 - val_auc: 0.8239
#
# Epoch 00079: val_auc did not improve from 0.82535
# Epoch 80/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3701 - auc: 0.8454 - val_loss: 0.3909 - val_auc: 0.8229
#
# Epoch 00080: val_auc did not improve from 0.82535
# Epoch 81/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3699 - auc: 0.8451 - val_loss: 0.3888 - val_auc: 0.8243
#
# Epoch 00081: val_auc did not improve from 0.82535
# Epoch 82/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3681 - auc: 0.8471 - val_loss: 0.3901 - val_auc: 0.8238
#
# Epoch 00082: val_auc did not improve from 0.82535
# Epoch 83/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3688 - auc: 0.8459 - val_loss: 0.3903 - val_auc: 0.8226
#
# Epoch 00083: val_auc did not improve from 0.82535
# Epoch 84/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3681 - auc: 0.8466 - val_loss: 0.3914 - val_auc: 0.8217
#
# Epoch 00084: val_auc did not improve from 0.82535
# Epoch 85/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3679 - auc: 0.8472 - val_loss: 0.3892 - val_auc: 0.8231
#
# Epoch 00085: val_auc did not improve from 0.82535
# Epoch 86/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3666 - auc: 0.8480 - val_loss: 0.3904 - val_auc: 0.8222
#
# Epoch 00086: val_auc did not improve from 0.82535
# Epoch 87/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3680 - auc: 0.8467 - val_loss: 0.3929 - val_auc: 0.8206
#
# Epoch 00087: val_auc did not improve from 0.82535
# Epoch 88/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3662 - auc: 0.8492 - val_loss: 0.3924 - val_auc: 0.8208
#
# Epoch 00088: val_auc did not improve from 0.82535
# Epoch 89/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3667 - auc: 0.8484 - val_loss: 0.3927 - val_auc: 0.8220
#
# Epoch 00089: val_auc did not improve from 0.82535
# Epoch 90/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3655 - auc: 0.8491 - val_loss: 0.3903 - val_auc: 0.8222
#
# Epoch 00090: val_auc did not improve from 0.82535
# Epoch 91/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3648 - auc: 0.8501 - val_loss: 0.3923 - val_auc: 0.8221
#
# Epoch 00091: val_auc did not improve from 0.82535
# Epoch 92/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3651 - auc: 0.8501 - val_loss: 0.4034 - val_auc: 0.8192
#
# Epoch 00092: val_auc did not improve from 0.82535
# Epoch 93/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3662 - auc: 0.8478 - val_loss: 0.3905 - val_auc: 0.8211
#
# Epoch 00093: val_auc did not improve from 0.82535
# Epoch 94/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3653 - auc: 0.8497 - val_loss: 0.3918 - val_auc: 0.8193
#
# Epoch 00094: val_auc did not improve from 0.82535
# Epoch 95/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3646 - auc: 0.8504 - val_loss: 0.3921 - val_auc: 0.8223
#
# Epoch 00095: val_auc did not improve from 0.82535
# Epoch 96/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3620 - auc: 0.8528 - val_loss: 0.3915 - val_auc: 0.8215
#
# Epoch 00096: val_auc did not improve from 0.82535
# Epoch 97/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3624 - auc: 0.8519 - val_loss: 0.3929 - val_auc: 0.8210
#
# Epoch 00097: val_auc did not improve from 0.82535
# Epoch 98/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3615 - auc: 0.8531 - val_loss: 0.3949 - val_auc: 0.8208
#
# Epoch 00098: val_auc did not improve from 0.82535
# Epoch 99/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3617 - auc: 0.8522 - val_loss: 0.3962 - val_auc: 0.8205
#
# Epoch 00099: val_auc did not improve from 0.82535
# Epoch 100/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3614 - auc: 0.8535 - val_loss: 0.3948 - val_auc: 0.8186
#
# Epoch 00100: val_auc did not improve from 0.82535
# Epoch 101/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3606 - auc: 0.8537 - val_loss: 0.3926 - val_auc: 0.8209
#
# Epoch 00101: val_auc did not improve from 0.82535
# Epoch 102/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3604 - auc: 0.8550 - val_loss: 0.3936 - val_auc: 0.8180
#
# Epoch 00102: val_auc did not improve from 0.82535
# Epoch 103/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3612 - auc: 0.8534 - val_loss: 0.3940 - val_auc: 0.8186
#
# Epoch 00103: val_auc did not improve from 0.82535
# Epoch 104/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3594 - auc: 0.8545 - val_loss: 0.3937 - val_auc: 0.8210
#
# Epoch 00104: val_auc did not improve from 0.82535
# Epoch 105/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3586 - auc: 0.8558 - val_loss: 0.3965 - val_auc: 0.8199
#
# Epoch 00105: val_auc did not improve from 0.82535
# Epoch 106/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3586 - auc: 0.8555 - val_loss: 0.3943 - val_auc: 0.8221
#
# Epoch 00106: val_auc did not improve from 0.82535
# Epoch 107/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3577 - auc: 0.8563 - val_loss: 0.3957 - val_auc: 0.8177
#
# Epoch 00107: val_auc did not improve from 0.82535
# Epoch 108/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3562 - auc: 0.8580 - val_loss: 0.3940 - val_auc: 0.8205
#
# Epoch 00108: val_auc did not improve from 0.82535
# Epoch 109/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3551 - auc: 0.8587 - val_loss: 0.4008 - val_auc: 0.8169
#
# Epoch 00109: val_auc did not improve from 0.82535
# Epoch 110/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3568 - auc: 0.8568 - val_loss: 0.3960 - val_auc: 0.8193
#
# Epoch 00110: val_auc did not improve from 0.82535
# Epoch 111/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3547 - auc: 0.8589 - val_loss: 0.3968 - val_auc: 0.8184
#
# Epoch 00111: val_auc did not improve from 0.82535
# Epoch 112/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3538 - auc: 0.8603 - val_loss: 0.3969 - val_auc: 0.8186
#
# Epoch 00112: val_auc did not improve from 0.82535
# Epoch 113/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3542 - auc: 0.8592 - val_loss: 0.3954 - val_auc: 0.8188
#
# Epoch 00113: val_auc did not improve from 0.82535
# Epoch 114/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3538 - auc: 0.8599 - val_loss: 0.3957 - val_auc: 0.8193
#
# Epoch 00114: val_auc did not improve from 0.82535
# Epoch 115/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3535 - auc: 0.8605 - val_loss: 0.3975 - val_auc: 0.8180
#
# Epoch 00115: val_auc did not improve from 0.82535
# Epoch 116/150
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3528 - auc: 0.8605 - val_loss: 0.3985 - val_auc: 0.8174
#
# Epoch 00116: val_auc did not improve from 0.82535
# Epoch 117/150
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3513 - auc: 0.8625 - val_loss: 0.3982 - val_auc: 0.8181
#
# Epoch 00117: val_auc did not improve from 0.82535
# Epoch 118/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3510 - auc: 0.8621 - val_loss: 0.3981 - val_auc: 0.8168
#
# Epoch 00118: val_auc did not improve from 0.82535
# Epoch 119/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3496 - auc: 0.8632 - val_loss: 0.3988 - val_auc: 0.8168
#
# Epoch 00119: val_auc did not improve from 0.82535
# Epoch 120/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3493 - auc: 0.8642 - val_loss: 0.3992 - val_auc: 0.8137
#
# Epoch 00120: val_auc did not improve from 0.82535
# Epoch 121/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3505 - auc: 0.8630 - val_loss: 0.3981 - val_auc: 0.8183
#
# Epoch 00121: val_auc did not improve from 0.82535
# Epoch 122/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3486 - auc: 0.8641 - val_loss: 0.4009 - val_auc: 0.8160
#
# Epoch 00122: val_auc did not improve from 0.82535
# Epoch 123/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3478 - auc: 0.8652 - val_loss: 0.4009 - val_auc: 0.8141
#
# Epoch 00123: val_auc did not improve from 0.82535
# Epoch 124/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3468 - auc: 0.8654 - val_loss: 0.3980 - val_auc: 0.8165
#
# Epoch 00124: val_auc did not improve from 0.82535
# Epoch 125/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3463 - auc: 0.8661 - val_loss: 0.4021 - val_auc: 0.8133
#
# Epoch 00125: val_auc did not improve from 0.82535
# Epoch 126/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3455 - auc: 0.8673 - val_loss: 0.4026 - val_auc: 0.8134
#
# Epoch 00126: val_auc did not improve from 0.82535
# Epoch 127/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3466 - auc: 0.8654 - val_loss: 0.4048 - val_auc: 0.8178
#
# Epoch 00127: val_auc did not improve from 0.82535
# Epoch 128/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3450 - auc: 0.8672 - val_loss: 0.4003 - val_auc: 0.8146
#
# Epoch 00128: val_auc did not improve from 0.82535
# Epoch 129/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3449 - auc: 0.8675 - val_loss: 0.4054 - val_auc: 0.8124
#
# Epoch 00129: val_auc did not improve from 0.82535
# Epoch 130/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3448 - auc: 0.8675 - val_loss: 0.4008 - val_auc: 0.8131
#
# Epoch 00130: val_auc did not improve from 0.82535
# Epoch 131/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3434 - auc: 0.8689 - val_loss: 0.4027 - val_auc: 0.8142
#
# Epoch 00131: val_auc did not improve from 0.82535
# Epoch 132/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3419 - auc: 0.8698 - val_loss: 0.4029 - val_auc: 0.8164
#
# Epoch 00132: val_auc did not improve from 0.82535
# Epoch 133/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3418 - auc: 0.8694 - val_loss: 0.4037 - val_auc: 0.8145
#
# Epoch 00133: val_auc did not improve from 0.82535
# Epoch 134/150
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3411 - auc: 0.8706 - val_loss: 0.4042 - val_auc: 0.8108
#
# Epoch 00134: val_auc did not improve from 0.82535
# Epoch 135/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3414 - auc: 0.8704 - val_loss: 0.4047 - val_auc: 0.8123
#
# Epoch 00135: val_auc did not improve from 0.82535
# Epoch 136/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3391 - auc: 0.8733 - val_loss: 0.4050 - val_auc: 0.8139
#
# Epoch 00136: val_auc did not improve from 0.82535
# Epoch 137/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3377 - auc: 0.8736 - val_loss: 0.4037 - val_auc: 0.8119
#
# Epoch 00137: val_auc did not improve from 0.82535
# Epoch 138/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3379 - auc: 0.8737 - val_loss: 0.4041 - val_auc: 0.8120
#
# Epoch 00138: val_auc did not improve from 0.82535
# Epoch 139/150
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3375 - auc: 0.8742 - val_loss: 0.4077 - val_auc: 0.8078
#
# Epoch 00139: val_auc did not improve from 0.82535
# Epoch 140/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3373 - auc: 0.8742 - val_loss: 0.4063 - val_auc: 0.8126
#
# Epoch 00140: val_auc did not improve from 0.82535
# Epoch 141/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3355 - auc: 0.8755 - val_loss: 0.4061 - val_auc: 0.8103
#
# Epoch 00141: val_auc did not improve from 0.82535
# Epoch 142/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3352 - auc: 0.8756 - val_loss: 0.4057 - val_auc: 0.8130
#
# Epoch 00142: val_auc did not improve from 0.82535
# Epoch 143/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3339 - auc: 0.8766 - val_loss: 0.4127 - val_auc: 0.8089
#
# Epoch 00143: val_auc did not improve from 0.82535
# Epoch 144/150
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3335 - auc: 0.8774 - val_loss: 0.4106 - val_auc: 0.8100
#
# Epoch 00144: val_auc did not improve from 0.82535
# Epoch 145/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3323 - auc: 0.8780 - val_loss: 0.4116 - val_auc: 0.8076
#
# Epoch 00145: val_auc did not improve from 0.82535
# Epoch 146/150
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3327 - auc: 0.8773 - val_loss: 0.4115 - val_auc: 0.8128
#
# Epoch 00146: val_auc did not improve from 0.82535
# Epoch 147/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3316 - auc: 0.8792 - val_loss: 0.4077 - val_auc: 0.8092
#
# Epoch 00147: val_auc did not improve from 0.82535
# Epoch 148/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3312 - auc: 0.8790 - val_loss: 0.4120 - val_auc: 0.8074
#
# Epoch 00148: val_auc did not improve from 0.82535
# Epoch 149/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.3295 - auc: 0.8807 - val_loss: 0.4116 - val_auc: 0.8081
#
# Epoch 00149: val_auc did not improve from 0.82535
# Epoch 150/150
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3295 - auc: 0.8799 - val_loss: 0.4162 - val_auc: 0.8084
#
# Epoch 00150: val_auc did not improve from 0.82535

# %%
model_h1n1 = load_model('..Models/h1n1_best_model.h5')

y_predicted_h1n1 = model_h1n1.predict(X_test)
roc_auc_score(y_test_h1n1, y_predicted_h1n1)
# Out:
# 0.8254230555587214

# %% [markdown]
# ### Seasonal

# %%
from tensorflow import keras
from keras.callbacks import ModelCheckpoint

seas_mc = ModelCheckpoint('..Models/seas_best_model.h5', monitor='val_auc_1', mode='max', verbose=1, save_best_only=True)


model_seas = keras.Sequential([
    keras.layers.Dense(100, activation='hard_sigmoid', input_dim=32),
    keras.layers.LeakyReLU(500),
    keras.layers.LeakyReLU(600),
    keras.layers.LeakyReLU(820),
    keras.layers.Dense(200, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model_seas.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=[tf.keras.metrics.AUC(from_logits=True)])

# %%
history = model_seas.fit(
    X_train,
    y_train_seas,
    batch_size=200,
    epochs=150,
    validation_data=(X_test, y_test_seas),
    callbacks=[seas_mc]
)
# Out:
# Epoch 1/150
# 94/94 [==============================] - 1s 4ms/step - loss: 0.5618 - auc_1: 0.7880 - val_loss: 0.5243 - val_auc_1: 0.8321
#
# Epoch 00001: val_auc_1 improved from -inf to 0.83209, saving model to ..Models\seas_best_model.h5
# Epoch 2/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5103 - auc_1: 0.8285 - val_loss: 0.4964 - val_auc_1: 0.8394
#
# Epoch 00002: val_auc_1 improved from 0.83209 to 0.83935, saving model to ..Models\seas_best_model.h5
# Epoch 3/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5034 - auc_1: 0.8335 - val_loss: 0.4964 - val_auc_1: 0.8407
#
# Epoch 00003: val_auc_1 improved from 0.83935 to 0.84070, saving model to ..Models\seas_best_model.h5
# Epoch 4/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5010 - auc_1: 0.8352 - val_loss: 0.4929 - val_auc_1: 0.8413
#
# Epoch 00004: val_auc_1 improved from 0.84070 to 0.84133, saving model to ..Models\seas_best_model.h5
# Epoch 5/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5008 - auc_1: 0.8354 - val_loss: 0.4964 - val_auc_1: 0.8418
#
# Epoch 00005: val_auc_1 improved from 0.84133 to 0.84184, saving model to ..Models\seas_best_model.h5
# Epoch 6/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5000 - auc_1: 0.8358 - val_loss: 0.4902 - val_auc_1: 0.8429
#
# Epoch 00006: val_auc_1 improved from 0.84184 to 0.84286, saving model to ..Models\seas_best_model.h5
# Epoch 7/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4996 - auc_1: 0.8360 - val_loss: 0.4974 - val_auc_1: 0.8436
#
# Epoch 00007: val_auc_1 improved from 0.84286 to 0.84364, saving model to ..Models\seas_best_model.h5
# Epoch 8/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4992 - auc_1: 0.8364 - val_loss: 0.4916 - val_auc_1: 0.8434
#
# Epoch 00008: val_auc_1 did not improve from 0.84364
# Epoch 9/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4972 - auc_1: 0.8379 - val_loss: 0.4887 - val_auc_1: 0.8444
#
# Epoch 00009: val_auc_1 improved from 0.84364 to 0.84440, saving model to ..Models\seas_best_model.h5
# Epoch 10/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4984 - auc_1: 0.8370 - val_loss: 0.4874 - val_auc_1: 0.8446
#
# Epoch 00010: val_auc_1 improved from 0.84440 to 0.84465, saving model to ..Models\seas_best_model.h5
# Epoch 11/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4969 - auc_1: 0.8379 - val_loss: 0.4871 - val_auc_1: 0.8450
#
# Epoch 00011: val_auc_1 improved from 0.84465 to 0.84502, saving model to ..Models\seas_best_model.h5
# Epoch 12/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4956 - auc_1: 0.8390 - val_loss: 0.4875 - val_auc_1: 0.8449
#
# Epoch 00012: val_auc_1 did not improve from 0.84502
# Epoch 13/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4945 - auc_1: 0.8397 - val_loss: 0.4865 - val_auc_1: 0.8465
#
# Epoch 00013: val_auc_1 improved from 0.84502 to 0.84648, saving model to ..Models\seas_best_model.h5
# Epoch 14/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4944 - auc_1: 0.8398 - val_loss: 0.4858 - val_auc_1: 0.8464
#
# Epoch 00014: val_auc_1 did not improve from 0.84648
# Epoch 15/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4942 - auc_1: 0.8401 - val_loss: 0.4937 - val_auc_1: 0.8463
#
# Epoch 00015: val_auc_1 did not improve from 0.84648
# Epoch 16/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4930 - auc_1: 0.8409 - val_loss: 0.4844 - val_auc_1: 0.8468
#
# Epoch 00016: val_auc_1 improved from 0.84648 to 0.84676, saving model to ..Models\seas_best_model.h5
# Epoch 17/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4911 - auc_1: 0.8423 - val_loss: 0.4846 - val_auc_1: 0.8471
#
# Epoch 00017: val_auc_1 improved from 0.84676 to 0.84711, saving model to ..Models\seas_best_model.h5
# Epoch 18/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4919 - auc_1: 0.8418 - val_loss: 0.4844 - val_auc_1: 0.8471
#
# Epoch 00018: val_auc_1 did not improve from 0.84711
# Epoch 19/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4907 - auc_1: 0.8425 - val_loss: 0.4857 - val_auc_1: 0.8473
#
# Epoch 00019: val_auc_1 improved from 0.84711 to 0.84734, saving model to ..Models\seas_best_model.h5
# Epoch 20/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4915 - auc_1: 0.8419 - val_loss: 0.4868 - val_auc_1: 0.8471
#
# Epoch 00020: val_auc_1 did not improve from 0.84734
# Epoch 21/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4904 - auc_1: 0.8429 - val_loss: 0.4911 - val_auc_1: 0.8477
#
# Epoch 00021: val_auc_1 improved from 0.84734 to 0.84770, saving model to ..Models\seas_best_model.h5
# Epoch 22/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4891 - auc_1: 0.8439 - val_loss: 0.4831 - val_auc_1: 0.8477
#
# Epoch 00022: val_auc_1 improved from 0.84770 to 0.84774, saving model to ..Models\seas_best_model.h5
# Epoch 23/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4889 - auc_1: 0.8440 - val_loss: 0.4838 - val_auc_1: 0.8478
#
# Epoch 00023: val_auc_1 improved from 0.84774 to 0.84782, saving model to ..Models\seas_best_model.h5
# Epoch 24/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4884 - auc_1: 0.8442 - val_loss: 0.4884 - val_auc_1: 0.8477
#
# Epoch 00024: val_auc_1 did not improve from 0.84782
# Epoch 25/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4895 - auc_1: 0.8433 - val_loss: 0.4831 - val_auc_1: 0.8478
#
# Epoch 00025: val_auc_1 improved from 0.84782 to 0.84784, saving model to ..Models\seas_best_model.h5
# Epoch 26/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4876 - auc_1: 0.8447 - val_loss: 0.4848 - val_auc_1: 0.8485
#
# Epoch 00026: val_auc_1 improved from 0.84784 to 0.84854, saving model to ..Models\seas_best_model.h5
# Epoch 27/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4888 - auc_1: 0.8439 - val_loss: 0.4836 - val_auc_1: 0.8475
#
# Epoch 00027: val_auc_1 did not improve from 0.84854
# Epoch 28/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4887 - auc_1: 0.8440 - val_loss: 0.4895 - val_auc_1: 0.8472
#
# Epoch 00028: val_auc_1 did not improve from 0.84854
# Epoch 29/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4877 - auc_1: 0.8448 - val_loss: 0.4864 - val_auc_1: 0.8486
#
# Epoch 00029: val_auc_1 improved from 0.84854 to 0.84864, saving model to ..Models\seas_best_model.h5
# Epoch 30/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4857 - auc_1: 0.8463 - val_loss: 0.4831 - val_auc_1: 0.8485
#
# Epoch 00030: val_auc_1 did not improve from 0.84864
# Epoch 31/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4860 - auc_1: 0.8460 - val_loss: 0.4844 - val_auc_1: 0.8482
#
# Epoch 00031: val_auc_1 did not improve from 0.84864
# Epoch 32/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4855 - auc_1: 0.8464 - val_loss: 0.4819 - val_auc_1: 0.8490
#
# Epoch 00032: val_auc_1 improved from 0.84864 to 0.84903, saving model to ..Models\seas_best_model.h5
# Epoch 33/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4858 - auc_1: 0.8461 - val_loss: 0.4866 - val_auc_1: 0.8486
#
# Epoch 00033: val_auc_1 did not improve from 0.84903
# Epoch 34/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4850 - auc_1: 0.8469 - val_loss: 0.4812 - val_auc_1: 0.8492
#
# Epoch 00034: val_auc_1 improved from 0.84903 to 0.84919, saving model to ..Models\seas_best_model.h5
# Epoch 35/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4855 - auc_1: 0.8462 - val_loss: 0.4813 - val_auc_1: 0.8487
#
# Epoch 00035: val_auc_1 did not improve from 0.84919
# Epoch 36/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4840 - auc_1: 0.8474 - val_loss: 0.4818 - val_auc_1: 0.8488
#
# Epoch 00036: val_auc_1 did not improve from 0.84919
# Epoch 37/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4840 - auc_1: 0.8474 - val_loss: 0.4879 - val_auc_1: 0.8487
#
# Epoch 00037: val_auc_1 did not improve from 0.84919
# Epoch 38/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4842 - auc_1: 0.8472 - val_loss: 0.4825 - val_auc_1: 0.8489
#
# Epoch 00038: val_auc_1 did not improve from 0.84919
# Epoch 39/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4841 - auc_1: 0.8475 - val_loss: 0.4805 - val_auc_1: 0.8495
#
# Epoch 00039: val_auc_1 improved from 0.84919 to 0.84946, saving model to ..Models\seas_best_model.h5
# Epoch 40/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4837 - auc_1: 0.8476 - val_loss: 0.4812 - val_auc_1: 0.8489
#
# Epoch 00040: val_auc_1 did not improve from 0.84946
# Epoch 41/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4842 - auc_1: 0.8471 - val_loss: 0.4819 - val_auc_1: 0.8485
#
# Epoch 00041: val_auc_1 did not improve from 0.84946
# Epoch 42/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4835 - auc_1: 0.8479 - val_loss: 0.4828 - val_auc_1: 0.8481
#
# Epoch 00042: val_auc_1 did not improve from 0.84946
# Epoch 43/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4815 - auc_1: 0.8491 - val_loss: 0.4838 - val_auc_1: 0.8481
#
# Epoch 00043: val_auc_1 did not improve from 0.84946
# Epoch 44/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4821 - auc_1: 0.8488 - val_loss: 0.4805 - val_auc_1: 0.8495
#
# Epoch 00044: val_auc_1 improved from 0.84946 to 0.84947, saving model to ..Models\seas_best_model.h5
# Epoch 45/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4833 - auc_1: 0.8479 - val_loss: 0.4810 - val_auc_1: 0.8491
#
# Epoch 00045: val_auc_1 did not improve from 0.84947
# Epoch 46/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4815 - auc_1: 0.8492 - val_loss: 0.4835 - val_auc_1: 0.8480
#
# Epoch 00046: val_auc_1 did not improve from 0.84947
# Epoch 47/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4811 - auc_1: 0.8494 - val_loss: 0.4821 - val_auc_1: 0.8489
#
# Epoch 00047: val_auc_1 did not improve from 0.84947
# Epoch 48/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4807 - auc_1: 0.8496 - val_loss: 0.4885 - val_auc_1: 0.8500
#
# Epoch 00048: val_auc_1 improved from 0.84947 to 0.85003, saving model to ..Models\seas_best_model.h5
# Epoch 49/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4812 - auc_1: 0.8494 - val_loss: 0.4830 - val_auc_1: 0.8482
#
# Epoch 00049: val_auc_1 did not improve from 0.85003
# Epoch 50/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4812 - auc_1: 0.8492 - val_loss: 0.4821 - val_auc_1: 0.8495
#
# Epoch 00050: val_auc_1 did not improve from 0.85003
# Epoch 51/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4796 - auc_1: 0.8505 - val_loss: 0.4836 - val_auc_1: 0.8490
#
# Epoch 00051: val_auc_1 did not improve from 0.85003
# Epoch 52/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4807 - auc_1: 0.8494 - val_loss: 0.4837 - val_auc_1: 0.8485
#
# Epoch 00052: val_auc_1 did not improve from 0.85003
# Epoch 53/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4804 - auc_1: 0.8501 - val_loss: 0.4822 - val_auc_1: 0.8486
#
# Epoch 00053: val_auc_1 did not improve from 0.85003
# Epoch 54/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4791 - auc_1: 0.8509 - val_loss: 0.4832 - val_auc_1: 0.8492
#
# Epoch 00054: val_auc_1 did not improve from 0.85003
# Epoch 55/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4808 - auc_1: 0.8496 - val_loss: 0.4802 - val_auc_1: 0.8498
#
# Epoch 00055: val_auc_1 did not improve from 0.85003
# Epoch 56/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4788 - auc_1: 0.8509 - val_loss: 0.4842 - val_auc_1: 0.8492
#
# Epoch 00056: val_auc_1 did not improve from 0.85003
# Epoch 57/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4783 - auc_1: 0.8514 - val_loss: 0.4812 - val_auc_1: 0.8493
#
# Epoch 00057: val_auc_1 did not improve from 0.85003
# Epoch 58/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4776 - auc_1: 0.8517 - val_loss: 0.4803 - val_auc_1: 0.8505
#
# Epoch 00058: val_auc_1 improved from 0.85003 to 0.85052, saving model to ..Models\seas_best_model.h5
# Epoch 59/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4771 - auc_1: 0.8524 - val_loss: 0.4809 - val_auc_1: 0.8495
#
# Epoch 00059: val_auc_1 did not improve from 0.85052
# Epoch 60/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4772 - auc_1: 0.8521 - val_loss: 0.4852 - val_auc_1: 0.8492
#
# Epoch 00060: val_auc_1 did not improve from 0.85052
# Epoch 61/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4773 - auc_1: 0.8520 - val_loss: 0.4809 - val_auc_1: 0.8492
#
# Epoch 00061: val_auc_1 did not improve from 0.85052
# Epoch 62/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4775 - auc_1: 0.8519 - val_loss: 0.4833 - val_auc_1: 0.8496
#
# Epoch 00062: val_auc_1 did not improve from 0.85052
# Epoch 63/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4772 - auc_1: 0.8521 - val_loss: 0.4800 - val_auc_1: 0.8500
#
# Epoch 00063: val_auc_1 did not improve from 0.85052
# Epoch 64/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4753 - auc_1: 0.8535 - val_loss: 0.4822 - val_auc_1: 0.8492
#
# Epoch 00064: val_auc_1 did not improve from 0.85052
# Epoch 65/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4772 - auc_1: 0.8520 - val_loss: 0.4805 - val_auc_1: 0.8498
#
# Epoch 00065: val_auc_1 did not improve from 0.85052
# Epoch 66/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4755 - auc_1: 0.8532 - val_loss: 0.4826 - val_auc_1: 0.8493
#
# Epoch 00066: val_auc_1 did not improve from 0.85052
# Epoch 67/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4749 - auc_1: 0.8536 - val_loss: 0.4806 - val_auc_1: 0.8498
#
# Epoch 00067: val_auc_1 did not improve from 0.85052
# Epoch 68/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4737 - auc_1: 0.8546 - val_loss: 0.4868 - val_auc_1: 0.8463
#
# Epoch 00068: val_auc_1 did not improve from 0.85052
# Epoch 69/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4750 - auc_1: 0.8536 - val_loss: 0.4835 - val_auc_1: 0.8481
#
# Epoch 00069: val_auc_1 did not improve from 0.85052
# Epoch 70/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4749 - auc_1: 0.8536 - val_loss: 0.4831 - val_auc_1: 0.8481
#
# Epoch 00070: val_auc_1 did not improve from 0.85052
# Epoch 71/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4733 - auc_1: 0.8547 - val_loss: 0.4834 - val_auc_1: 0.8487
#
# Epoch 00071: val_auc_1 did not improve from 0.85052
# Epoch 72/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4741 - auc_1: 0.8542 - val_loss: 0.4884 - val_auc_1: 0.8496
#
# Epoch 00072: val_auc_1 did not improve from 0.85052
# Epoch 73/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4732 - auc_1: 0.8548 - val_loss: 0.4823 - val_auc_1: 0.8492
#
# Epoch 00073: val_auc_1 did not improve from 0.85052
# Epoch 74/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4720 - auc_1: 0.8558 - val_loss: 0.4903 - val_auc_1: 0.8490
#
# Epoch 00074: val_auc_1 did not improve from 0.85052
# Epoch 75/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4721 - auc_1: 0.8555 - val_loss: 0.4825 - val_auc_1: 0.8482
#
# Epoch 00075: val_auc_1 did not improve from 0.85052
# Epoch 76/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4716 - auc_1: 0.8559 - val_loss: 0.4818 - val_auc_1: 0.8489
#
# Epoch 00076: val_auc_1 did not improve from 0.85052
# Epoch 77/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4715 - auc_1: 0.8561 - val_loss: 0.4831 - val_auc_1: 0.8484
#
# Epoch 00077: val_auc_1 did not improve from 0.85052
# Epoch 78/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4714 - auc_1: 0.8561 - val_loss: 0.4823 - val_auc_1: 0.8492
#
# Epoch 00078: val_auc_1 did not improve from 0.85052
# Epoch 79/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4710 - auc_1: 0.8564 - val_loss: 0.4821 - val_auc_1: 0.8489
#
# Epoch 00079: val_auc_1 did not improve from 0.85052
# Epoch 80/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4708 - auc_1: 0.8563 - val_loss: 0.4824 - val_auc_1: 0.8484
#
# Epoch 00080: val_auc_1 did not improve from 0.85052
# Epoch 81/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4697 - auc_1: 0.8570 - val_loss: 0.4834 - val_auc_1: 0.8475
#
# Epoch 00081: val_auc_1 did not improve from 0.85052
# Epoch 82/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4701 - auc_1: 0.8570 - val_loss: 0.4841 - val_auc_1: 0.8478
#
# Epoch 00082: val_auc_1 did not improve from 0.85052
# Epoch 83/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4692 - auc_1: 0.8575 - val_loss: 0.4842 - val_auc_1: 0.8482
#
# Epoch 00083: val_auc_1 did not improve from 0.85052
# Epoch 84/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4687 - auc_1: 0.8579 - val_loss: 0.4825 - val_auc_1: 0.8483
#
# Epoch 00084: val_auc_1 did not improve from 0.85052
# Epoch 85/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4690 - auc_1: 0.8579 - val_loss: 0.4842 - val_auc_1: 0.8475
#
# Epoch 00085: val_auc_1 did not improve from 0.85052
# Epoch 86/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4690 - auc_1: 0.8577 - val_loss: 0.4860 - val_auc_1: 0.8476
#
# Epoch 00086: val_auc_1 did not improve from 0.85052
# Epoch 87/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4685 - auc_1: 0.8580 - val_loss: 0.4837 - val_auc_1: 0.8486
#
# Epoch 00087: val_auc_1 did not improve from 0.85052
# Epoch 88/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4668 - auc_1: 0.8592 - val_loss: 0.4839 - val_auc_1: 0.8473
#
# Epoch 00088: val_auc_1 did not improve from 0.85052
# Epoch 89/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4667 - auc_1: 0.8592 - val_loss: 0.4887 - val_auc_1: 0.8454
#
# Epoch 00089: val_auc_1 did not improve from 0.85052
# Epoch 90/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4681 - auc_1: 0.8581 - val_loss: 0.4844 - val_auc_1: 0.8469
#
# Epoch 00090: val_auc_1 did not improve from 0.85052
# Epoch 91/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4661 - auc_1: 0.8595 - val_loss: 0.4878 - val_auc_1: 0.8475
#
# Epoch 00091: val_auc_1 did not improve from 0.85052
# Epoch 92/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4664 - auc_1: 0.8594 - val_loss: 0.4851 - val_auc_1: 0.8466
#
# Epoch 00092: val_auc_1 did not improve from 0.85052
# Epoch 93/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4649 - auc_1: 0.8602 - val_loss: 0.4844 - val_auc_1: 0.8471
#
# Epoch 00093: val_auc_1 did not improve from 0.85052
# Epoch 94/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4647 - auc_1: 0.8605 - val_loss: 0.4898 - val_auc_1: 0.8451
#
# Epoch 00094: val_auc_1 did not improve from 0.85052
# Epoch 95/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4650 - auc_1: 0.8604 - val_loss: 0.4861 - val_auc_1: 0.8473
#
# Epoch 00095: val_auc_1 did not improve from 0.85052
# Epoch 96/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4647 - auc_1: 0.8604 - val_loss: 0.4913 - val_auc_1: 0.8452
#
# Epoch 00096: val_auc_1 did not improve from 0.85052
# Epoch 97/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4649 - auc_1: 0.8604 - val_loss: 0.4868 - val_auc_1: 0.8462
#
# Epoch 00097: val_auc_1 did not improve from 0.85052
# Epoch 98/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4627 - auc_1: 0.8617 - val_loss: 0.4892 - val_auc_1: 0.8449
#
# Epoch 00098: val_auc_1 did not improve from 0.85052
# Epoch 99/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4633 - auc_1: 0.8613 - val_loss: 0.4874 - val_auc_1: 0.8458
#
# Epoch 00099: val_auc_1 did not improve from 0.85052
# Epoch 100/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4629 - auc_1: 0.8615 - val_loss: 0.4876 - val_auc_1: 0.8452
#
# Epoch 00100: val_auc_1 did not improve from 0.85052
# Epoch 101/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4616 - auc_1: 0.8627 - val_loss: 0.4853 - val_auc_1: 0.8469
#
# Epoch 00101: val_auc_1 did not improve from 0.85052
# Epoch 102/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4617 - auc_1: 0.8624 - val_loss: 0.4925 - val_auc_1: 0.8441
#
# Epoch 00102: val_auc_1 did not improve from 0.85052
# Epoch 103/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4605 - auc_1: 0.8634 - val_loss: 0.4897 - val_auc_1: 0.8455
#
# Epoch 00103: val_auc_1 did not improve from 0.85052
# Epoch 104/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4621 - auc_1: 0.8623 - val_loss: 0.4872 - val_auc_1: 0.8457
#
# Epoch 00104: val_auc_1 did not improve from 0.85052
# Epoch 105/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4598 - auc_1: 0.8635 - val_loss: 0.4892 - val_auc_1: 0.8438
#
# Epoch 00105: val_auc_1 did not improve from 0.85052
# Epoch 106/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4585 - auc_1: 0.8645 - val_loss: 0.4891 - val_auc_1: 0.8444
#
# Epoch 00106: val_auc_1 did not improve from 0.85052
# Epoch 107/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4581 - auc_1: 0.8649 - val_loss: 0.4935 - val_auc_1: 0.8435
#
# Epoch 00107: val_auc_1 did not improve from 0.85052
# Epoch 108/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4593 - auc_1: 0.8639 - val_loss: 0.4906 - val_auc_1: 0.8437
#
# Epoch 00108: val_auc_1 did not improve from 0.85052
# Epoch 109/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4589 - auc_1: 0.8644 - val_loss: 0.4899 - val_auc_1: 0.8456
#
# Epoch 00109: val_auc_1 did not improve from 0.85052
# Epoch 110/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4574 - auc_1: 0.8652 - val_loss: 0.4902 - val_auc_1: 0.8451
#
# Epoch 00110: val_auc_1 did not improve from 0.85052
# Epoch 111/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4580 - auc_1: 0.8648 - val_loss: 0.4893 - val_auc_1: 0.8440
#
# Epoch 00111: val_auc_1 did not improve from 0.85052
# Epoch 112/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4562 - auc_1: 0.8661 - val_loss: 0.4917 - val_auc_1: 0.8440
#
# Epoch 00112: val_auc_1 did not improve from 0.85052
# Epoch 113/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4559 - auc_1: 0.8662 - val_loss: 0.4922 - val_auc_1: 0.8438
#
# Epoch 00113: val_auc_1 did not improve from 0.85052
# Epoch 114/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4559 - auc_1: 0.8663 - val_loss: 0.4929 - val_auc_1: 0.8442
#
# Epoch 00114: val_auc_1 did not improve from 0.85052
# Epoch 115/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4547 - auc_1: 0.8668 - val_loss: 0.4954 - val_auc_1: 0.8429
#
# Epoch 00115: val_auc_1 did not improve from 0.85052
# Epoch 116/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4543 - auc_1: 0.8672 - val_loss: 0.4985 - val_auc_1: 0.8443
#
# Epoch 00116: val_auc_1 did not improve from 0.85052
# Epoch 117/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4537 - auc_1: 0.8676 - val_loss: 0.4942 - val_auc_1: 0.8419
#
# Epoch 00117: val_auc_1 did not improve from 0.85052
# Epoch 118/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4545 - auc_1: 0.8671 - val_loss: 0.4930 - val_auc_1: 0.8440
#
# Epoch 00118: val_auc_1 did not improve from 0.85052
# Epoch 119/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4531 - auc_1: 0.8679 - val_loss: 0.4925 - val_auc_1: 0.8430
#
# Epoch 00119: val_auc_1 did not improve from 0.85052
# Epoch 120/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4523 - auc_1: 0.8686 - val_loss: 0.4919 - val_auc_1: 0.8431
#
# Epoch 00120: val_auc_1 did not improve from 0.85052
# Epoch 121/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4518 - auc_1: 0.8688 - val_loss: 0.4944 - val_auc_1: 0.8428
#
# Epoch 00121: val_auc_1 did not improve from 0.85052
# Epoch 122/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4519 - auc_1: 0.8689 - val_loss: 0.4986 - val_auc_1: 0.8398
#
# Epoch 00122: val_auc_1 did not improve from 0.85052
# Epoch 123/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4504 - auc_1: 0.8698 - val_loss: 0.4942 - val_auc_1: 0.8406
#
# Epoch 00123: val_auc_1 did not improve from 0.85052
# Epoch 124/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4509 - auc_1: 0.8693 - val_loss: 0.4966 - val_auc_1: 0.8424
#
# Epoch 00124: val_auc_1 did not improve from 0.85052
# Epoch 125/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4493 - auc_1: 0.8704 - val_loss: 0.4958 - val_auc_1: 0.8417
#
# Epoch 00125: val_auc_1 did not improve from 0.85052
# Epoch 126/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4496 - auc_1: 0.8704 - val_loss: 0.4977 - val_auc_1: 0.8397
#
# Epoch 00126: val_auc_1 did not improve from 0.85052
# Epoch 127/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4484 - auc_1: 0.8710 - val_loss: 0.4970 - val_auc_1: 0.8416
#
# Epoch 00127: val_auc_1 did not improve from 0.85052
# Epoch 128/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4479 - auc_1: 0.8713 - val_loss: 0.4998 - val_auc_1: 0.8398
#
# Epoch 00128: val_auc_1 did not improve from 0.85052
# Epoch 129/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4471 - auc_1: 0.8717 - val_loss: 0.4996 - val_auc_1: 0.8412
#
# Epoch 00129: val_auc_1 did not improve from 0.85052
# Epoch 130/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4471 - auc_1: 0.8718 - val_loss: 0.4965 - val_auc_1: 0.8425
#
# Epoch 00130: val_auc_1 did not improve from 0.85052
# Epoch 131/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4491 - auc_1: 0.8703 - val_loss: 0.4968 - val_auc_1: 0.8398
#
# Epoch 00131: val_auc_1 did not improve from 0.85052
# Epoch 132/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4447 - auc_1: 0.8732 - val_loss: 0.4992 - val_auc_1: 0.8395
#
# Epoch 00132: val_auc_1 did not improve from 0.85052
# Epoch 133/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4454 - auc_1: 0.8728 - val_loss: 0.4998 - val_auc_1: 0.8409
#
# Epoch 00133: val_auc_1 did not improve from 0.85052
# Epoch 134/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4446 - auc_1: 0.8731 - val_loss: 0.4984 - val_auc_1: 0.8388
#
# Epoch 00134: val_auc_1 did not improve from 0.85052
# Epoch 135/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4427 - auc_1: 0.8744 - val_loss: 0.4995 - val_auc_1: 0.8396
#
# Epoch 00135: val_auc_1 did not improve from 0.85052
# Epoch 136/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4434 - auc_1: 0.8741 - val_loss: 0.4997 - val_auc_1: 0.8379
#
# Epoch 00136: val_auc_1 did not improve from 0.85052
# Epoch 137/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4413 - auc_1: 0.8754 - val_loss: 0.5001 - val_auc_1: 0.8384
#
# Epoch 00137: val_auc_1 did not improve from 0.85052
# Epoch 138/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4416 - auc_1: 0.8751 - val_loss: 0.5026 - val_auc_1: 0.8381
#
# Epoch 00138: val_auc_1 did not improve from 0.85052
# Epoch 139/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4426 - auc_1: 0.8745 - val_loss: 0.4997 - val_auc_1: 0.8388
#
# Epoch 00139: val_auc_1 did not improve from 0.85052
# Epoch 140/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4396 - auc_1: 0.8763 - val_loss: 0.5024 - val_auc_1: 0.8368
#
# Epoch 00140: val_auc_1 did not improve from 0.85052
# Epoch 141/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4400 - auc_1: 0.8761 - val_loss: 0.5009 - val_auc_1: 0.8380
#
# Epoch 00141: val_auc_1 did not improve from 0.85052
# Epoch 142/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4392 - auc_1: 0.8765 - val_loss: 0.5084 - val_auc_1: 0.8347
#
# Epoch 00142: val_auc_1 did not improve from 0.85052
# Epoch 143/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4383 - auc_1: 0.8773 - val_loss: 0.5025 - val_auc_1: 0.8384
#
# Epoch 00143: val_auc_1 did not improve from 0.85052
# Epoch 144/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4381 - auc_1: 0.8772 - val_loss: 0.5039 - val_auc_1: 0.8370
#
# Epoch 00144: val_auc_1 did not improve from 0.85052
# Epoch 145/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4371 - auc_1: 0.8779 - val_loss: 0.5043 - val_auc_1: 0.8391
#
# Epoch 00145: val_auc_1 did not improve from 0.85052
# Epoch 146/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4367 - auc_1: 0.8782 - val_loss: 0.5042 - val_auc_1: 0.8382
#
# Epoch 00146: val_auc_1 did not improve from 0.85052
# Epoch 147/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4352 - auc_1: 0.8791 - val_loss: 0.5061 - val_auc_1: 0.8392
#
# Epoch 00147: val_auc_1 did not improve from 0.85052
# Epoch 148/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4363 - auc_1: 0.8783 - val_loss: 0.5072 - val_auc_1: 0.8361
#
# Epoch 00148: val_auc_1 did not improve from 0.85052
# Epoch 149/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4341 - auc_1: 0.8795 - val_loss: 0.5047 - val_auc_1: 0.8373
#
# Epoch 00149: val_auc_1 did not improve from 0.85052
# Epoch 150/150
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4328 - auc_1: 0.8804 - val_loss: 0.5054 - val_auc_1: 0.8366
#
# Epoch 00150: val_auc_1 did not improve from 0.85052

# %%
model_seas = load_model('..Models/seas_best_model.h5')

y_predicted_seas = model_seas.predict(X_test)
roc_auc_score(y_test_seas, y_predicted_seas)
# Out:
# 0.8505707400027179

# %%
y_predicted_h1n1 = model_h1n1.predict(X_test)
y_predicted_seas = model_seas.predict(X_test)
y_predicted = np.concatenate((y_predicted_h1n1, y_predicted_seas), axis=1)
roc_auc_score(y_test, y_predicted)
# Out:
# 0.8379968977807197

# %% [markdown]
# # Submission Data

# %%
test_data = pd.read_csv('../Data/test_set_features.csv')
df_full = test_data
df = test_data

# %%
df['sex'] = df['sex'].map({
    'Female': 0,
    'Male': 1
})

df['marital_status'] = df['marital_status'].map({
    'Not Married': 0,
    'Married': 1
})

df['rent_or_own'] = df['rent_or_own'].map({
    'Rent': 0,
    'Own': 1
})
    
h1n1_num_cols = [
    'opinion_h1n1_sick_from_vacc',
    'h1n1_concern',
    'h1n1_knowledge',
    'opinion_seas_vacc_effective',
    'opinion_h1n1_vacc_effective',
    'opinion_seas_risk',
    'opinion_h1n1_risk',
    'child_under_6_months',
    'marital_status',
    'rent_or_own',
    'behavioral_touch_face',
    'behavioral_face_mask',
    'chronic_med_condition',
    'behavioral_wash_hands',
    'doctor_recc_seasonal',
    'doctor_recc_h1n1'
]

h1n1_cat_cols = [
    'age_group',
    'hhs_geo_region',
    'income_poverty'
]

seas_num_cols = [
    'behavioral_wash_hands',
    'opinion_h1n1_vacc_effective',
    'opinion_h1n1_risk',
    'opinion_seas_vacc_effective',
    'opinion_seas_risk',
    'marital_status',
    'chronic_med_condition',
    'rent_or_own',
    'doctor_recc_h1n1',
    'doctor_recc_seasonal'
]

seas_cat_cols = [
    'age_group',
    'income_poverty'
]

h1n1_cols = h1n1_num_cols + h1n1_cat_cols
seas_cols = seas_num_cols + seas_cat_cols

num_cols = list(set(h1n1_num_cols + seas_num_cols))
cat_cols = list(set(h1n1_cat_cols + seas_cat_cols))

all_cols = list(set(num_cols + cat_cols))

# %%
df['opinion_h1n1_sick_from_vacc'] = df['opinion_h1n1_sick_from_vacc'].fillna(opinion_h1n1_sick_from_vacc_mean)
df['h1n1_concern'] = df['h1n1_concern'].fillna(h1n1_concern_mean)
df['h1n1_knowledge'] = df['h1n1_knowledge'].fillna(h1n1_knowledge_mean)
df['opinion_seas_vacc_effective'] = df['opinion_seas_vacc_effective'].fillna(opinion_seas_vacc_effective_mean)
df['opinion_h1n1_vacc_effective'] = df['opinion_h1n1_vacc_effective'].fillna(opinion_h1n1_vacc_effective_mean)
df['opinion_seas_risk'] = df['opinion_seas_risk'].fillna(opinion_seas_risk_mean)
df['opinion_h1n1_risk'] = df['opinion_h1n1_risk'].fillna(opinion_h1n1_risk_mean)
df['behavioral_wash_hands'] = df['behavioral_wash_hands'].fillna(behavioral_wash_hands_mean)
df['sex'] = df['sex'].fillna(sex_mean)
df['child_under_6_months'] = df['child_under_6_months'].fillna(child_under_6_months_mean)
df['marital_status'] = df['marital_status'].fillna(marital_status_mean)
df['rent_or_own'] = df['rent_or_own'].fillna(rent_or_own_mean)
df['behavioral_touch_face'] = df['behavioral_touch_face'].fillna(behavioral_touch_face_mean)
df['behavioral_face_mask'] = df['behavioral_face_mask'].fillna(behavioral_face_mask_mean)
df['chronic_med_condition'] = df['chronic_med_condition'].fillna(chronic_med_condition_mean)
df['doctor_recc_seasonal'] = df['doctor_recc_seasonal'].fillna(doctor_recc_seasonal_mean)
df['doctor_recc_h1n1'] = df['doctor_recc_h1n1'].fillna(doctor_recc_h1n1_mean)

df['age_group'] = df['age_group'].fillna('None')
df['income_poverty'] = df['income_poverty'].fillna('None')
df['hhs_geo_region'] = df['hhs_geo_region'].fillna('None')

# %%
X = df[all_cols]

# %%
#Categorical
cat_df = X[cat_cols]
recat_df = pd.get_dummies(data=cat_df, drop_first=True)

#Numerical
num_df = X[num_cols]

scaled_num = scaler.transform(num_df)
scaled_num_df = pd.DataFrame(scaled_num, index=num_df.index, columns=num_df.columns)

encoded_df = pd.concat([recat_df, scaled_num_df], axis=1)

encoded_df['opinion_seas_risk'] = encoded_df['opinion_seas_risk'] * 1
encoded_df['opinion_h1n1_risk'] = encoded_df['opinion_h1n1_risk'] * 1

X = np.asarray(encoded_df)

# %%
model_h1n1 = load_model('..Models/h1n1_best_model.h5')
model_seas = load_model('..Models/seas_best_model.h5')

# %%
y_h1n1 = model_h1n1.predict(X)
y_seas = model_seas.predict(X)

y = np.concatenate((y_h1n1, y_seas), axis=1)

# %%
results = pd.DataFrame(y, columns=['h1n1_vaccine', 'seasonal_vaccine'])

submission = pd.concat([df_full, results], axis=1)
submission = submission[['respondent_id', 'h1n1_vaccine', 'seasonal_vaccine']]

# %%
today = datetime.today().date()

submission.to_csv(f'../Data/Neural Network Submission {today}.csv', index=False)

# %%
print(datetime.today().date())
# Out:
# 2021-07-02

# %% [markdown]
# # Test

# %%
training_features = pd.read_csv('../Data/training_set_features.csv')
training_targets = pd.read_csv('../Data/training_set_labels.csv')
df_full = pd.merge(training_features, training_targets, on='respondent_id', how='left')
df = df_full

# %%
df['sex'] = df['sex'].map({
    'Female': 0,
    'Male': 1
})

df['marital_status'] = df['marital_status'].map({
    'Not Married': 0,
    'Married': 1
})

df['rent_or_own'] = df['rent_or_own'].map({
    'Rent': 0,
    'Own': 1
})
    
h1n1_num_cols = [
    'opinion_h1n1_sick_from_vacc',
    'h1n1_concern',
    'h1n1_knowledge',
    'opinion_seas_vacc_effective',
    'opinion_h1n1_vacc_effective',
    'opinion_seas_risk',
    'opinion_h1n1_risk',
    'child_under_6_months',
    'marital_status',
    'rent_or_own',
    'behavioral_touch_face',
    'behavioral_face_mask',
    'chronic_med_condition',
    'behavioral_wash_hands',
    'doctor_recc_seasonal',
    'doctor_recc_h1n1'
]

h1n1_cat_cols = [
    'age_group',
    'hhs_geo_region',
    'income_poverty'
]

seas_num_cols = [
    'behavioral_wash_hands',
    'opinion_h1n1_vacc_effective',
    'opinion_h1n1_risk',
    'opinion_seas_vacc_effective',
    'opinion_seas_risk',
    'marital_status',
    'chronic_med_condition',
    'rent_or_own',
    'doctor_recc_h1n1',
    'doctor_recc_seasonal'
]

seas_cat_cols = [
    'age_group',
    'income_poverty'
]

h1n1_cols = h1n1_num_cols + h1n1_cat_cols
seas_cols = seas_num_cols + seas_cat_cols

num_cols = list(set(h1n1_num_cols + seas_num_cols))
cat_cols = list(set(h1n1_cat_cols + seas_cat_cols))

all_cols = list(set(num_cols + cat_cols))

# %%
df['opinion_h1n1_sick_from_vacc'] = df['opinion_h1n1_sick_from_vacc'].fillna(opinion_h1n1_sick_from_vacc_mean)
df['h1n1_concern'] = df['h1n1_concern'].fillna(h1n1_concern_mean)
df['h1n1_knowledge'] = df['h1n1_knowledge'].fillna(h1n1_knowledge_mean)
df['opinion_seas_vacc_effective'] = df['opinion_seas_vacc_effective'].fillna(opinion_seas_vacc_effective_mean)
df['opinion_h1n1_vacc_effective'] = df['opinion_h1n1_vacc_effective'].fillna(opinion_h1n1_vacc_effective_mean)
df['opinion_seas_risk'] = df['opinion_seas_risk'].fillna(opinion_seas_risk_mean)
df['opinion_h1n1_risk'] = df['opinion_h1n1_risk'].fillna(opinion_h1n1_risk_mean)
df['behavioral_wash_hands'] = df['behavioral_wash_hands'].fillna(behavioral_wash_hands_mean)
df['sex'] = df['sex'].fillna(sex_mean)
df['child_under_6_months'] = df['child_under_6_months'].fillna(child_under_6_months_mean)
df['marital_status'] = df['marital_status'].fillna(marital_status_mean)
df['rent_or_own'] = df['rent_or_own'].fillna(rent_or_own_mean)
df['behavioral_touch_face'] = df['behavioral_touch_face'].fillna(behavioral_touch_face_mean)
df['behavioral_face_mask'] = df['behavioral_face_mask'].fillna(behavioral_face_mask_mean)
df['chronic_med_condition'] = df['chronic_med_condition'].fillna(chronic_med_condition_mean)
df['doctor_recc_seasonal'] = df['doctor_recc_seasonal'].fillna(doctor_recc_seasonal_mean)
df['doctor_recc_h1n1'] = df['doctor_recc_h1n1'].fillna(doctor_recc_h1n1_mean)

df['age_group'] = df['age_group'].fillna('None')
df['income_poverty'] = df['income_poverty'].fillna('None')
df['hhs_geo_region'] = df['hhs_geo_region'].fillna('None')

# %%
X = df[all_cols]
y = df[['h1n1_vaccine', 'seasonal_vaccine']]

# %%
#Categorical
cat_df = X[cat_cols]
recat_df = pd.get_dummies(data=cat_df, drop_first=True)

#Numerical
num_df = X[num_cols]

scaled_num = scaler.transform(num_df)
scaled_num_df = pd.DataFrame(scaled_num, index=num_df.index, columns=num_df.columns)

encoded_df = pd.concat([recat_df, scaled_num_df], axis=1)

encoded_df['opinion_seas_risk'] = encoded_df['opinion_seas_risk'] * 1
encoded_df['opinion_h1n1_risk'] = encoded_df['opinion_h1n1_risk'] * 1

X = np.asarray(encoded_df)

# %%
model_h1n1 = load_model('..Models/h1n1_best_model.h5')
model_seas = load_model('..Models/seas_best_model.h5')

# %%
y_h1n1 = model_h1n1.predict(X)
y_seas = model_seas.predict(X)

y_comb = np.concatenate((y_h1n1, y_seas), axis=1)

# %%
results = pd.DataFrame(y_comb, columns=['h1n1_vaccine_pred', 'seasonal_vaccine_pred'])

submission = pd.concat([df_full, results], axis=1)
submission = submission[['respondent_id', 'h1n1_vaccine', 'h1n1_vaccine_pred', 'seasonal_vaccine', 'seasonal_vaccine_pred']]

# %%
y_true = np.asarray(submission[['h1n1_vaccine', 'seasonal_vaccine']])
y_pred = np.asarray(submission[['h1n1_vaccine_pred', 'seasonal_vaccine_pred']])

# %%
roc_auc_score(y_true, y_pred)
# Out:
# 0.8460556503605772
